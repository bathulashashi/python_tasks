# %%
#module: varibale +nfunction+class
#user defined modules--->  .py ....ex..variables,functions,class
#predefined modules: built in modules---->random,math,datetimr,time
# third party modules: pyttsx3,pandas,numpy ---> which are insatlled usind pip install pandas
#random.random() it print random no b/w 0 and 1
import random
print(random.randint(1,20))
for i in range(5):
    print(random.randint(10,29))
print(random.randrange(0,20,4))#it give the from, to with step
# Out:
# 13
# 24
# 15
# 19
# 12
# 26
# 8

# %%
while True:
    a=random.randint(1,10)
    print(a)
    b=int(input('guess a number'))
    
    if a!=b:
        print('you loose')
    else:
        print('you won')
    break
# Out:
# 10
# guess a number 5
# you loose

# %%
pl1=0
pl2=0
while True:
    p1=input('press enter p1')
    if p1=='':
        r=random.randint(1,6)
        pl1+=r
        if pl1>=20:
            print('p1 won the match')
            break
    p2=input('press enter p2')
    if p2=='':
        r1=random.randint(1,6)
        pl2+=r1
        if pl2>=20:
            print('p2 won the match')
            break
# Out:
# press enter p1 44
# press enter p2 4
# press enter p1 5
# press enter p2
# press enter p1
# press enter p2
# press enter p1
# press enter p2
# press enter p1
# press enter p2
# press enter p1
# press enter p2
# press enter p1
# press enter p2
# p2 won the match

# %%
print(random.uniform(10,20))# which is genereats random number as float number
# Out:
# 12.792109391073367

# %%
for i in range(5):
    print(random.uniform(1,20))
# Out:
# 15.868610896806196
# 11.851250812227562
# 19.847395698861
# 8.855665642980899
# 7.39815088281286

# %%
print(random.choice('shashichandra'))#is used to pick a random character or letter or word from the given string 
print(random.choice(['sai','hari','shashi']))
# Out:
# a
# sai

# %%
import random
for i in range(2):
    print(random.choice(['shashi', 'chandra','bathula','sai']))
# Out:
# sai
# bathula

# %%
#randint,randrange,randchoice,uniform
al=int(input())
num1=int(input())
sp=int(input())
password=''
for i in range(num1):
    a=random.choice('0123456789')
    password+=a
for i in range(sp):
    b=random.choice('abcdefghijklmno')
    password+=b
for i in range(sp):
    c=random.choice('!@#$%^&*')
    password+=c
print(password)
# Out:
#  4
#  4
#  4
# 9748laac%^%!

# %%
#choices:it select k no.of characters without using loops as output
#
print(random.choices('shashi',k=5))
# Out:
# ['h', 's', 'a', 'h', 'h']

# %%
q=['shashi', 'chandra','bathula','sai']
print(random.choices(q,k=2))
# Out:
# ['chandra', 'bathula']

# %%
a=int(input('alphab'))
b=int(input('num'))
c=int(input('special char'))
p=random.choices('abcdefghijklmnopqrstuvwxyz',k=a)
q=random.choices('0123456789',k=b)
r=random.choices('!@#$%^&*',k=c)
pasw=p+q+r
print(''.join(pasw))
# Out:
# alphab 4
# num 5
# special char 5
# zylk97827$@@@$

# %%
#sample:it gives k.no of characters where the length ois less than are equal to k value
print(random.sample('shashi',k=6))
# print(random.sample('shashi',k=7)) # example for smaple where k value is more than the lenght ofthe charcater
# Out:
# ['i', 'h', 's', 'a', 'h', 's']

# %%
# import pyttsx3
# e=pyttsx3.init()
# e.setProperty('rate',120)
# v=e.getProperty('voices')
# e.setProperty('voice',voice[1].id)
# e.say('helloooo shashi')
# e.runAndWait()

# %%
#packing and unpacking 
'''
# l=['1','2','3',4]
# a,b,c,d=l
# print(d)
# '''
m=[1,23,5,6,5,7,5,6]
a,*b,c=m
print(b)
# Out:
# [23, 5, 6, 5, 7, 5]

# %%
def se(a,b):
    print(a+b)
s=20,30
se(*s)
# Out:
# 50

# %%
#lambda function
#filter function is used e=to filter the records
#map function ius used to perform operation on each value
#reduce functi

# %%
add1=lambda x,y:x+y
print(add1(1,2))
# Out:
# 3
