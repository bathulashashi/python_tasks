# %%
#If at least one of 2 values are present in the list, then print the  list,otherwise clear the list and print it.
a = [101, "Sai", "it"]
value1 = input()
value2 = input()
# Check condition
if value1 in a or value2 in a:
    print("List:", a)
else:
    a.clear()
    print("List after clearing:", a)
# Out:
#  shashi
#  it
# List: [101, 'Sai', 'it']
